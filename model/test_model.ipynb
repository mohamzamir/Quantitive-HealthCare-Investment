# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from tqdm.notebook import tqdm
from joblib import dump, load

# %%
mlp_classifier = load('/storage/ice1/1/7/khayashi31/Hacklytics/Model/trained_mlp_model.joblib')

# %%
mlp_classifier
# Out:
# MLPClassifier(learning_rate='adaptive', verbose=True)

# %%
test_data = pd.read_csv('/storage/ice1/1/7/khayashi31/Hacklytics/feature_engineering_data.csv', skiprows=range(1, int(.98*34085)))

# %%
y = test_data['label']
X = test_data.drop(columns=['Unnamed: 0', 'Brief Summary', 'Conditions', 'Interventions', 'Primary Outcome Measures', 'Secondary Outcome Measures',
                'Other Outcome Measures', 'Sponsor', 'Collaborators', 'Sex', 'Age', 'Phases', 'Enrollment', 'Funder Type', 'Study Type', 'Study Design', 'label', 'Allocation', 'Intervention Model', 'Masking', 'Primary Purpose'] )

# %%
X
# Out:
#      female  male  Funder_Type_FED  Funder_Type_INDIV  Funder_Type_INDUSTRY  \
# 0         1     1            False              False                 False
# 1         1     1            False              False                 False
# 2         1     1            False              False                 False
# 3         1     1            False              False                 False
# 4         1     1            False              False                 False
# ..      ...   ...              ...                ...                   ...
# 678       1     1            False              False                  True
# 679       1     1            False              False                  True
# 680       1     1            False              False                 False
# 681       1     1            False              False                 False
# 682       1     1            False              False                  True
#
#      Funder_Type_NETWORK  Funder_Type_NIH  Funder_Type_OTHER  \
# 0                  False            False               True
# 1                  False            False               True
# 2                  False            False               True
# 3                  False            False               True
# 4                  False            False               True
# ..                   ...              ...                ...
# 678                False            False              False
# 679                False            False              False
# 680                False            False               True
# 681                False            False               True
# 682                False            False              False
#
#      Funder_Type_OTHER_GOV  Funder_Type_UNKNOWN  ...  \
# 0                    False                False  ...
# 1                    False                False  ...
# 2                    False                False  ...
# 3                    False                False  ...
# 4                    False                False  ...
# ..                     ...                  ...  ...
# 678                  False                False  ...
# 679                  False                False  ...
# 680                  False                False  ...
# 681                  False                False  ...
# 682                  False                False  ...
#
#      other_outcome_measures_vector_374  other_outcome_measures_vector_375  \
# 0                            -0.201059                           0.218681
# 1                             0.130234                          -0.190815
# 2                             0.130234                          -0.190815
# 3                             0.130234                          -0.190815
# 4                             0.130234                          -0.190815
# ..                                 ...                                ...
# 678                           0.130234                          -0.190815
# 679                           0.130234                          -0.190815
# 680                           0.130234                          -0.190815
# 681                           0.130234                          -0.190815
# 682                           0.130234                          -0.190815
#
#      other_outcome_measures_vector_376  other_outcome_measures_vector_377  \
# 0                            -0.244830                          -0.037846
# 1                            -0.050503                           0.256153
# 2                            -0.050503                           0.256153
# 3                            -0.050503                           0.256153
# 4                            -0.050503                           0.256153
# ..                                 ...                                ...
# 678                          -0.050503                           0.256153
# 679                          -0.050503                           0.256153
# 680                          -0.050503                           0.256153
# 681                          -0.050503                           0.256153
# 682                          -0.050503                           0.256153
#
#      other_outcome_measures_vector_378  other_outcome_measures_vector_379  \
# 0                            -0.113514                          -0.144362
# 1                             0.615008                          -0.006029
# 2                             0.615008                          -0.006029
# 3                             0.615008                          -0.006029
# 4                             0.615008                          -0.006029
# ..                                 ...                                ...
# 678                           0.615008                          -0.006029
# 679                           0.615008                          -0.006029
# 680                           0.615008                          -0.006029
# 681                           0.615008                          -0.006029
# 682                           0.615008                          -0.006029
#
#      other_outcome_measures_vector_380  other_outcome_measures_vector_381  \
# 0                             0.127571                           0.065967
# 1                             0.632454                           0.035349
# 2                             0.632454                           0.035349
# 3                             0.632454                           0.035349
# 4                             0.632454                           0.035349
# ..                                 ...                                ...
# 678                           0.632454                           0.035349
# 679                           0.632454                           0.035349
# 680                           0.632454                           0.035349
# 681                           0.632454                           0.035349
# 682                           0.632454                           0.035349
#
#      other_outcome_measures_vector_382  other_outcome_measures_vector_383
# 0                            -0.032978                           0.021158
# 1                            -0.244361                           0.165219
# 2                            -0.244361                           0.165219
# 3                            -0.244361                           0.165219
# 4                            -0.244361                           0.165219
# ..                                 ...                                ...
# 678                          -0.244361                           0.165219
# 679                          -0.244361                           0.165219
# 680                          -0.244361                           0.165219
# 681                          -0.244361                           0.165219
# 682                          -0.244361                           0.165219
#
# [683 rows x 11011 columns]

# %%
predicted_probs = pd.DataFrame(mlp_classifier.predict_proba(X))

# %%
predicted_probs
# Out:
#             0         1
# 0    0.980058  0.019942
# 1    0.990243  0.009757
# 2    0.996775  0.003225
# 3    0.999559  0.000441
# 4    0.990810  0.009190
# ..        ...       ...
# 678  0.990856  0.009144
# 679  0.993189  0.006811
# 680  0.994481  0.005519
# 681  0.992693  0.007307
# 682  0.983574  0.016426
#
# [683 rows x 2 columns]

# %%
result = pd.concat([predicted_probs.reset_index(drop=True), y.reset_index(drop=True)], axis=1)

# %%
result
# Out:
#             0         1  label
# 0    0.980058  0.019942      0
# 1    0.990243  0.009757      0
# 2    0.996775  0.003225      0
# 3    0.999559  0.000441      0
# 4    0.990810  0.009190      0
# ..        ...       ...    ...
# 678  0.990856  0.009144      0
# 679  0.993189  0.006811      0
# 680  0.994481  0.005519      0
# 681  0.992693  0.007307      0
# 682  0.983574  0.016426      0
#
# [683 rows x 3 columns]

# %%
result[result['label']==False].sort_values(0, ascending=True)
# Out:
#             0         1  label
# 147  0.543059  0.456941      0
# 475  0.587908  0.412092      0
# 498  0.594856  0.405144      0
# 96   0.638642  0.361358      0
# 449  0.722214  0.277786      0
# ..        ...       ...    ...
# 307  0.999726  0.000274      0
# 218  0.999738  0.000262      0
# 439  0.999749  0.000251      0
# 364  0.999769  0.000231      0
# 472  0.999885  0.000115      0
#
# [660 rows x 3 columns]
